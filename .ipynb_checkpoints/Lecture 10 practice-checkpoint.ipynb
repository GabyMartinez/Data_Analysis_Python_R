# %%
options("repos" = c(CRAN = "https://mirror.las.iastate.edu/CRAN/")) #setting CRAN anaconda does this automatically

# %%
install.packages('nycflights13') #install package
# Out:
# package 'nycflights13' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Gabrielle Martinez\AppData\Local\Temp\RtmpcfsMvQ\downloaded_packages

# %%
# import package
library('tidyverse')
library('nycflights13')
library('dplyr')

# %%
help(select)

# %%
setwd('~/eco590_Data_Analysis_Python_R/Lecture 8')

# %%
read.csv("job-automation-probability.csv") -> jobs

# %%
filter(jobs, !is.na(prob))
# Out:
#     X_...rank X_...code prob   Average.annual.wage
# 1   624       51-4033   0.9500 34920
# 2   517       51-9012   0.8800 41450
# 3   484       41-4012   0.8500 68410
# 4   105       53-1031   0.0290 59800
# 5   620       51-4072   0.9500 32660
# 6   518       51-6091   0.8800 35420
# 7   427       51-4031   0.7800 34210
# 8   228       41-4011   0.2500 92910
# 9   590       51-4032   0.9400 38880
# 10  584       51-9041   0.9300 34370
# 11  477       51-4034   0.8400 39630
# 12  560       51-4021   0.9100 35340
# 13  637       51-6064   0.9600 28110
# 14  323       37-1012   0.5700 48790
# 15  634       43-6014   0.9600 36140
# 16  554       49-2093   0.9100 59840
# 17  208       15-1179   0.2100 67770
# 18  678       51-4035   0.9800 41180
# 19  569       51-4193   0.9200 33690
# 20  254       49-2022   0.3600 54520
# 21  253       51-4012   0.3600 53560
# 22  548       51-3091   0.9100 30970
# 23  103       17-2111   0.0280 90190
# 24  205       25-3011   0.1900 55140
# ...

# %%
select(jobs, code=X_...code , rank= X_...rank)
Jobs2 <-rename(jobs, code=X_...code , rank= X_...rank)
# Out:
#     code    rank
# 1   51-4033 624
# 2   51-9012 517
# 3   41-4012 484
# 4   53-1031 105
# 5   51-4072 620
# 6   51-6091 518
# 7   51-4031 427
# 8   41-4011 228
# 9   51-4032 590
# 10  51-9041 584
# 11  51-4034 477
# 12  51-4021 560
# 13  51-6064 637
# 14  37-1012 323
# 15  43-6014 634
# 16  49-2093 554
# 17  15-1179 208
# 18  51-4035 678
# 19  51-4193 569
# 20  49-2022 254
# 21  51-4012 253
# 22  51-3091 548
# 23  17-2111 103
# 24  25-3011 205
# 25  49-2094 277
# 26  51-4191 556
# 27  47-3011 463
# 28  33-9092 373
# 29  43-5053 430
# 30  25-2031  41
# ... ...     ...
# 673 39-6012 211
# 674 19-3011 282
# 675 19-3093 283
# 676 25-4021 360
# 677 51-4041 358
# 678 19-2012 175
# 679 47-2151 345
# 680 39-5093 432
# 681 15-2011 209
# 682 39-4011 308
# 683 19-1032  43
# 684 17-1022 262
# 685 33-3011 252
# 686 41-2011 657
# 687 19-2031 173
# 688 25-4012  34
# 689 47-2121 402
# 690 39-5011 439
# 691 27-2031 179
# 692 27-3041 140
# 693 45-4021 418
# 694 23-1011 115
# 695 49-9096 527
# ...

# %%
Jobs2
# Out:
#     rank code    prob   Average.annual.wage education
# 1   624  51-4033 0.9500 34920               High school diploma or equivalent
# 2   517  51-9012 0.8800 41450               High school diploma or equivalent
# 3   484  41-4012 0.8500 68410               High school diploma or equivalent
# 4   105  53-1031 0.0290 59800               High school diploma or equivalent
# 5   620  51-4072 0.9500 32660               High school diploma or equivalent
# 6   518  51-6091 0.8800 35420               High school diploma or equivalent
# 7   427  51-4031 0.7800 34210               High school diploma or equivalent
# 8   228  41-4011 0.2500 92910               Bachelor's degree
# 9   590  51-4032 0.9400 38880               High school diploma or equivalent
# 10  584  51-9041 0.9300 34370               High school diploma or equivalent
# 11  477  51-4034 0.8400 39630               High school diploma or equivalent
# 12  560  51-4021 0.9100 35340               High school diploma or equivalent
# ...

# %%
mutate(jobs, diff = Average.annual.wage - median_ann_wage) ->jobs
jobs
# Out:
#     X_...rank X_...code prob   Average.annual.wage
# 1   624       51-4033   0.9500 34920
# 2   517       51-9012   0.8800 41450
# 3   484       41-4012   0.8500 68410
# 4   105       53-1031   0.0290 59800
# 5   620       51-4072   0.9500 32660
# 6   518       51-6091   0.8800 35420
# 7   427       51-4031   0.7800 34210
# 8   228       41-4011   0.2500 92910
# 9   590       51-4032   0.9400 38880
# 10  584       51-9041   0.9300 34370
# 11  477       51-4034   0.8400 39630
# 12  560       51-4021   0.9100 35340
# 13  637       51-6064   0.9600 28110
# 14  323       37-1012   0.5700 48790
# 15  634       43-6014   0.9600 36140
# 16  554       49-2093   0.9100 59840
# 17  208       15-1179   0.2100 67770
# 18  678       51-4035   0.9800 41180
# 19  569       51-4193   0.9200 33690
# 20  254       49-2022   0.3600 54520
# 21  253       51-4012   0.3600 53560
# 22  548       51-3091   0.9100 30970
# 23  103       17-2111   0.0280 90190
# 24  205       25-3011   0.1900 55140
# ...

# %%
transmute(jobs, diff = Average.annual.wage - median_ann_wage)
# Out:
#     diff
# 1    2030
# 2    3090
# 3   11270
# 4    2530
# 5    2180
# 6    1180
# 7    1840
# 8   13930
# 9    2470
# 10   1860
# 11   1150
# 12   1470
# 13    610
# 14   3050
# 15   1320
# 16    560
# 17   5100
# 18   1340
# 19   2410
# 20    880
# 21   2980
# 22   2400
# 23   3470
# 24   4490
# 25    740
# 26   1830
# 27   3040
# 28   2350
# 29  -6510
# 30   3390
# ... ...
# 673  2190.0
# 674 11810.0
# 675  5880.0
# 676  2190.0
# 677  1520.0
# 678  5900.0
# 679  4450.0
# 680  1260.0
# 681 13510.0
# 682  2110.0
# 683  1600.0
# 684  4090.0
# 685  3070.0
# 686  1500.0
# 687  7080.0
# 688  5550.0
# 689  5340.0
# 690  4140.0
# 691  8144.5
# 692  8870.0
# 693  5530.0
# 694 21720.0
# 695  3340.0
# 696  4320.0
# 697   800.0
# 698 37840.6
# 699  2020.0
# 700  3710.0
# 701 14690.0
# 702  4800.0

# %%
jobs %>% filter(occupation %in% c('Economists')) %>% mutate(diff = Average.annual.wage - median_ann_wage)
# Out:
#   X_...rank X_...code prob Average.annual.wage education       occupation
# 1 282       19-3011   0.43 112860              Master's degree Economists
#   short.occupation len probability numbEmployed median_ann_wage
# 1 Economists       10  0.43        19380        101050
#   employed_may2016 average_ann_wage diff
# 1 19380            112860           11810

# %%
summarise(jobs, prob = mean(prob, na.rm=TRUE))
# Out:
#   prob
# 1 0.5355499

# %%
by_educ <- group_by(jobs, education)

summarise(by_educ, av_pat = mean(Average.annual.wage, na.rm=TRUE),count = n())
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   education                         av_pat    count
# 1 Associate's degree                 56492.50  44
# 2 Bachelor's degree                  80601.74 155
# 3 Doctoral or professional degree   126743.04  23
# 4 High school diploma or equivalent  44011.50 307
# 5 Master's degree                    75965.86  29
# 6 No formal educational credential   33030.83  98
# 7 Postsecondary nondegree award      48555.48  42
# 8 Some college, no degree            44515.90   4
