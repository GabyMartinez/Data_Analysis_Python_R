# %% [markdown]
# HistPat.csv only has a patent#, years, an variable that says a

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 0E92-7058
#
#  Directory of C:\Users\Gabrielle Martinez\Documents\eco590_Data_Analysis_Python_R\Data Cleaning
#
# 10/07/2020  08:28 PM    <DIR>          .
# 10/07/2020  08:28 PM    <DIR>          ..
# 10/07/2020  06:09 PM       336,149,130 HistPat.csv
#                1 File(s)    336,149,130 bytes
#                2 Dir(s)  408,775,839,744 bytes free

# %%
#C:\Users\Gabrielle Martinez\Documents\eco590_Data_Analysis_Python_R\Data Cleaning

#import pandas
import pandas as pd

# %%
#import csv w latin encoding
histpat = pd.read_csv('HistPat.csv',sep = ',', encoding = 'latin1')

histpat
# Out:
#                 PN  Year      Type          City        County   FIPS State  \
# 0             USX2  1790  Inventor       SUFFOLK       SUFFOLK  25025    MA
# 1             USX3  1790  Inventor  PHILADELPHIA  PHILADELPHIA  42101    PA
# 2            USX10  1791  Inventor  PHILADELPHIA  PHILADELPHIA  42101    PA
# 3            USX11  1791  Inventor  PHILADELPHIA  PHILADELPHIA  42101    PA
# 4            USX12  1791  Inventor        MORRIS        MORRIS  34027    NJ
# ...            ...   ...       ...           ...           ...    ...   ...
# 4881334  US3930247  1975  Inventor         TONEY       MADISON   1089    AL
# 4881335  US3930248  1975  Inventor    ALEXANDRIA    ALEXANDRIA  51510    VA
# 4881336  US3930254  1975  Inventor        DALLAS        DALLAS  48113    TX
# 4881337  US3930255  1975  Inventor     SAN DIEGO     SAN DIEGO   6073    CA
# 4881338  US3930259  1975  Inventor     BEAVERTON    WASHINGTON  41067    OR
#
#         Accuracy
# 0         Medium
# 1         Medium
# ...

# %%
#filter dates down to 1972-1975

histpat1972_75 = histpat[histpat['Year']>=1972]
